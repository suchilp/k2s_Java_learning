# %%
x=10
y=1234566098764
print(x)
print(y)
# Out:
# 10
# 1234566098764

# %%
a=125E2
print(a)
# Out:
# 12500.0

# %%
a=29.75
b=-1.75
c=-2.5E2
d=-3.1E-2
print(a,b,c,d)
# Out:
# 29.75 -1.75 -250.0 -0.031
