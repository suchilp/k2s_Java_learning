# %%
2+2

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
print(fruits)

# %%
for x in fruits:
    print(x)

# %%
my_new_fruits_list=[]

print(my_new_fruits_list)

# %%
for x in fruits:
   my_new_fruits_list.append(x)

# %%
print(my_new_fruits_list)

# %%
my_new_fruits_list=[]
for x in fruits:
    if "e" in x:
        my_new_fruits_list.append(x)
        
print(my_new_fruits_list)

# %%
print(my_new_fruits_list)

# %%
my_new_fruits_list=[ x for x in fruits if x!="apple"]

# %%
my_new_fruits_list=[ x for x in fruits if x!="apple"]

# %%
my_new_fruits_list=[]
for x in fruits:
    if x!="apple" :
        my_new_fruits_list.append(x)
        
print(my_new_fruits_list)

# %%
newList=[ x.upper() for x in fruits]
print(newList)

# %%
print(fruits)
newList=[x if x != "banana" else "orange"  for x in fruits ]
print(newList)

# %%
fruits = ["mango","apple", "banana", "cherry", "kiwi"]
print(fruits)
fruits.sort(reverse=True)
print(fruits)

# %%
thislist = [100, 50, 65, 82, 23]
thislist.sort(reverse=True)
print(thislist)

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.sort(key=str.lower,reverse=True)
print(thislist)

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.reverse()
print(thislist)

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print(mylist)

# %%
thislist = ["apple", "banana", "cherry"]
mylist = list(thislist)
print(mylist)

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist[:]
print(mylist)

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

for x in list2:
  list1.append(x)

print(list1)

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

list1.extend(list2)
print(list1)

# %%
list1.

# %%
list=[1,2,3,5]
print(list)

# %%
print(list[3])

# %%
print(list[-1:])

# %%
list1=[1,2,3,5]
list2=[6,7,8,9]

list =list1+list2
print(list)

# %%
list.clear()
print(list)

# %%
print(list.clear())
for x in list1:
    list.append(x)

for x in list2:
    list.append(x)
    
print(list)

# %%
print(list.clear())
print(list)
list.extend(list1)
list.extend(list2)
print(list)
