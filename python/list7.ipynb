# %%
print("suchil")
# Out:
# suchil

# %%
mylist = ["apple","apple", "banana", "cherry"]

# %%
mylist
# Out:
# ['apple', 'apple', 'banana', 'cherry']

# %%
print( len(mylist))
# Out:
# 4

# %%
list=[1,"Suchil",False]

# %%
print(list)
# Out:
# [1, 'Suchil', False]

# %%
print(type(list))
# Out:
# <class 'list'>

# %%
thislist= list(("apple","apple", "banana", "cherry"))
print(thislist[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 thislist= list(("apple","apple", "banana", "cherry"))
#       2 print(thislist[0])
#
# TypeError: 'list' object is not callable

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist[-1])
# Out:
# cherry

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[2:5])
# Out:
# ['cherry', 'orange', 'kiwi']

# %%
print(thislist[:4])
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
print(thislist[2:])
# Out:
# ['cherry', 'orange', 'kiwi', 'melon', 'mango']

# %%
print(thislist[-4:-1])
# Out:
# ['orange', 'kiwi', 'melon']

# %%
if 'apple1' in thislist:
    print("Yes apple is in the list")
else:
    print("No apple not there ")
# Out:
# No apple not there

# %%
thislist[0]="apple1"
print(thislist)
# Out:
# ['apple1', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango']

# %%
thislist[1:3] =["banana1","cherry1"]
print(thislist)
# Out:
# ['apple1', 'banana1', 'cherry1', 'orange', 'kiwi', 'melon', 'mango']

# %%
thislist[1:3] =["banana2"]
print(thislist)
# Out:
# ['apple1', 'banana2', 'kiwi', 'melon', 'mango']

# %%
thislist.insert(3,"ORANGE")
print(thislist)
# Out:
# ['apple1', 'banana2', 'kiwi', 'ORANGE', 'ORANGE', 'melon', 'mango']

# %%
thislist.append("Watermelon")

# %%
print(thislist)
# Out:
# ['apple1', 'banana2', 'kiwi', 'ORANGE', 'ORANGE', 'melon', 'mango', 'Watermelon', 'Watermelon', 'Watermelon', 'Watermelon']

# %%
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %%
thislist.remove('apple1')
print(thislist)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 thislist.remove('apple1')
#       2 print(thislist)
#
# ValueError: list.remove(x): x not in list

# %%
thislist
# Out:
# ['banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %%
thislist.pop(0)
# Out:
# 'mango'

# %%
print(thislist)
# Out:
# ['pineapple', 'papaya']

# %%
thislist = ["apple", "banana", "cherry"]
del thislist[0]

# %%
print(thislist)
# Out:
# ['banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
del thislist
print(thislist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 3
#       1 thislist = ["apple", "banana", "cherry"]
#       2 del thislist
# ----> 3 print(thislist)
#
# NameError: name 'thislist' is not defined

# %%
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)
# Out:
# []

# %%
thislist = ["apple", "banana", "cherry"]
for x in thislist:
    print(x)
# Out:
# apple
# banana
# cherry

# %%
for i in range(len(thislist)):
    print(thislist[i])
# Out:
# apple
# banana
# cherry

# %%
i=0
while(i<len(thislist)):
    print(thislist[i])
    i=i+1
# Out:
# apple
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry"]
[print(x) for x in thislist]
# Out:
# apple
# banana
# cherry
# [None, None, None]
