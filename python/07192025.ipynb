# %%
print("suchil")
# Out:
# suchil

# %%
# and """ """"

# %%
name="suchil"
print(suchil)

# %%
name=str("suchil")
print(name)
# Out:
# suchil

# %%
 print(type(name))
# Out:
# <class 'str'>

# %%
Text Type: str,

Numeric : int , float , complex

Sequence data type: list, tuple and range

mapping data type : dict

Set : set, frozenset

Boolean : bool

Binary: bytes,bytearray and memoryview 
None :  NoneType
# Out:
#   Cell In[30], line 1
#     Text Type: str,
#          ^
# SyntaxError: invalid syntax

# %%
a="Suchil"
b=20
c=20.4
d=200j

print(type(d))
# Out:
# <class 'complex'>

# %%
x=["suchil","swati","pina","suchil","swati","pina"]
print(x)
print(type(x))
# Out:
# ['suchil', 'swati', 'pina', 'suchil', 'swati', 'pina']
# <class 'list'>

# %%
x=("suchil","swati","pina")
print(x)
print(type(x))
# Out:
# ('suchil', 'swati', 'pina')
# <class 'tuple'>

# %%
x =range(10)
print(x)
print( type(x))
# Out:
# range(0, 10)
# <class 'range'>

# %%
x={"suchil","swati","pina","suchil","swati","pina"}
print(x)
print(type(x))
# Out:
# {'swati', 'pina', 'suchil'}
# <class 'set'>

# %%
x={ "name":"suchil","job":"so"}
print(x)
# Out:
# {'fruit': 'apple', 'flower': 'rose'}

# %%
x = frozenset({"suchil","swati","pina","suchil","swati","pina"})

# %%
x=True
print(x)
# Out:
# True

# %%
x=b"Suchil"
print(x)
print(type(x))
# Out:
# b'Suchil'
# <class 'bytes'>

# %%
b=bytearray(5)

# %%
memoryview(bytearray(5))

# %%
x=None
print(x)
print(type(x))
# Out:
# None
# <class 'NoneType'>

# %%
import random
print(random.randrange(1,501))
# Out:
# 187

# %%
x=23.4
str(x)
# Out:
# '23.4'

# %%
print(x)
# Out:
# 23.4

# %%
s="Suchil Kumar Pradhan"

for a in s:
    print(a)
# Out:
# S
# u
# c
# h
# i
# l
#
# K
# u
# m
# a
# r
#
# P
# r
# a
# d
# h
# a
# n

# %%
for s in "orange":
    print(s)
# Out:
# o
# r
# a
# n
# g
# e

# %%
for n in "Pina":
    print(n)
# Out:
# P
# i
# n
# a

# %%
a="Pina"
print(len(a))
# Out:
# 4

# %%
txt = "My name is suchil kumar pradhn, i am going to india soon"
print("going1"  not in txt)
# Out:
# True

# %%
x="Samaira"

print(x[4])
# Out:
# i

# %%
txt = "My name is suchil kumar pradhn, i am going to india soon     "

print(txt[4:])
# Out:
# ame is suchil kumar pradhn, i am going to india soon

# %%
txt = "    My name is suchil kumar PRADHAN, i am going to india soon   "
print(txt.strip())
# Out:
#     My name is suchil kumar PRADHAN, i am going to india soon

# %%
txt = "My name is suchil kumar pradhn, i am going to india soon"
print(txt.replace("india","Mumbai"))
# Out:
# My name is suchil kumar pradhn, i am going to Mumbai soon

# %%
txt = "My name is suchil kumar pradhn, i am going to india soon, yes "
print(txt.split(""))
# Out:
# ['My name is suchil kumar pradhn', ' i am going to india soon', ' yes ']

# %%
#concantination of String 


a="Suchil"
b="Pradhan"
c=a+" "+b
print(c)
# Out:
# Suchil Pradhan

# %%
sal=20000
txt="My salary is "


txt=f"My current Salary is {sal:.5f}"
print(txt)
# Out:
# My current Salary is 20000.00000

# %%
txt=" My name is suchil kumar pradhan  and \"Pradhan\" is my famlily name"
print(txt)
# Out:
#  My name is suchil kumar pradhan  and "Pradhan" is my famlily name

# %%
s="suchil kumar pradhan"
print(s.capitalize())
# Out:
# Suchil kumar pradhan

# %%
s="suchil kumar pradhan"
print(s.upper())
# Out:
# SUCHIL KUMAR PRADHAN

# %%
s="suchil kumar pradhan"
print(s.count("r"))
# Out:
# 2

# %%
s="My name is Ståle"
print(s.encode())
# Out:
# b'My name is St\xc3\xa5le'

# %%
txt="price of Mango is {price:.2f}, dollars and color {color} "
print(txt.format(price=10.11111,color='red'))
# Out:
# price of Mango is 10.11, dollars and color red

# %%
s="suchil kumar pradhan"
print(s.index("r"))
print(s.isupper())
print(s.swapcase())
# Out:
# 11
# False
# SUCHIL KUMAR PRADHAN

# %%
x = 'Welcome'
print(x[3])
# Out:
# c

# %%
x = 'Welcome'
print(x[3:5]) # come , come
# Out:
# co

# %%
print(10<90)
# Out:
# True

# %%
print(100>100)
# Out:
# False

# %%
x=15
print(bool(x))
# Out:
# True

# %%
print(bool(False))
# Out:
# False

# %%
x="suchil"
print(bool(x))
# Out:
# True

# %%
print(bool({1,2,3}))
# Out:
# True

# %%
print(bool( {}))
# Out:
# False

# %%
bool(False)
bool(None)
bool(0)
bool("")
bool(())
bool([])
bool({})
# Out:
# False

# %%
def myFunction(age):
    if(age<10):
        return "I am young boy"
    elif(age<20):
        return  "I am adult "
    else:
        return "I am old "

print(myFunction(80))
# Out:
# I am old

# %%
thislist = ["apple", "banana", "cherry","cherry"]
print(thislist)
print(len(thislist))
# Out:
# ['apple', 'banana', 'cherry', 'cherry']
# 4
