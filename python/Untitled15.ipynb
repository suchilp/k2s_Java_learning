# %%
print("Suchil")
# Out:
# Suchil

# %%
print("Suchil,Pradhan")
# Out:
# Suchil,Pradhan

# %%
#print("Suchil")

"""
sdjfjsdfsjdfjsd
"""
print("Hello")
# Out:
# Hello

# %%
x=4;
y=6
print(x+y)
# Out:
# 10

# %%
x=10
y="suchil"
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 x=10
#       2 y="suchil"
# ----> 3 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x=4
x="suchil"
print(x)
# Out:
# suchil

# %%
x=5;
print(x)
x="Suchil"
print(type(x))

y=10;
print(type(y))
y=str(y)
print(type(y))

str()    convert   Integer.toString(). 
int()       
float()
# Out:
# 5
# <class 'str'>
# <class 'int'>
# <class 'str'>
