# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='Pierian_Data_Logo.png' /></a>
# ___
# # Welcome to the Course: 00 - End-to-End Python
#
# This notebook is your course roadmap for a complete **end-to-end Python journey**:
# - from core language fundamentals
# - to data analysis, visualization, and machine learning
# - through final real-world projects and deployment.
#
# ---
#
# ## 1. Course Goals
#
# 1. Master Python syntax and idioms
# 2. Build confidence with data structures, functions, and OOP
# 3. Use NumPy/Pandas for real datasets
# 4. Make plots with Matplotlib/Seaborn
# 5. Apply basic ML with scikit-learn
# 6. Complete 2+ portfolio projects
#
# ---
#
# ## 2. Module Outline
#
# 1. Python Crash Course (current folder: `01-Python-Crash-Course`)
#    - Python install + setup
#    - variables, types, math
#    - strings, lists, dicts, sets, tuples
#    - if/else, loops, comprehensions
#    - functions, lambda, args/kwargs
#    - files, exceptions, modules/packages
#
# 2. NumPy (03-04)**
#    - arrays, indexing, broadcasting
#    - vectorized operations, linear algebra
#
# 3. Pandas (03-05)**
#    - Series/DataFrame creation and summary
#    - join/merge, groupby, pivot
#    - cleaning missing data
#
# 4. Matplotlib / Seaborn (05-06)**
#    - line, bar, histogram, scatter, box
#    - subplots, style, color mappings
#
# 5. Machine Learning Intro
#    - regression, classification, clustering
#    - model pipeline, cross-validation
#
# 6. Advanced Python
#    - iterators/generators, decorators, context managers
#    - typing, unit test basics
#
# 7. Final Capstone
#    - end-to-end dataset project
#    - analysis report + visualization + model
#
# ---
#
# ## 3. Study Workflow (Weekly Plan)
#
# Week 1-2: Python and basic programming
# Week 3: NumPy and Pandas
# Week 4: Visualization + data storytelling
# Week 5: ML fundamentals
# Week 6: Capstone project + notebook portfolio
#
# ---
#
# ## 4. Core Reference Code (copy and run)
#
# ```python
# # Python core practice
# print('Hello, Python Course!')
#
# # Basic data struct
# nums = [1, 2, 3, 4, 5]
# doubles = [n*2 for n in nums if n%2==1]
# print('doubles', doubles)
#
# person = {'name':'Jane', 'score': 95}
# for k,v in person.items():
#     print(f'{k}: {v}')
#
# # function example
# def greet(name: str) -> str:
#     return f'Hello, {name}!'
#
# print(greet('Learner'))
# ```
#
# ---
#
# ## 5. Next Step
# Open `01-Python Crash Course/01-Python Crash Course.ipynb` and run the first cells. Then return here for the module checkpoint and practical exercises.
#
# ---
#
# ## 6. Notes
# - Track progress in this notebook by adding your own completion checkboxes.
# - Build one small project at end of each module.
# - Use Git commits for checkpoint history.
